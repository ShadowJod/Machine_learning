# %%
import numpy as np
import pandas as pd

# %%
a = pd.read_csv("placement.csv")

# %%
a.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
a = a.iloc[:,1:]

# %%
a.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt
import matplotlib.style as style

# %%
style.use("ggplot")
plt.scatter(a['cgpa'],a['iq'],c=a["placement"])
plt.xlabel("CGPA")
plt.ylabel("IQ")
plt.title("Placement data")
plt.show()

# %%
x = a.iloc[:,0:2]
y = a.iloc[:,-1]

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

# %%
#train and test split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 13   6.4  116.0
# 70   6.3  127.0
# 83   7.5  130.0
# 15   5.1  176.0
# 57   6.5  130.0
# ..   ...    ...
# 62   6.0  102.0
# 29   7.0  112.0
# 71   6.1  132.0
# 63   6.3  128.0
# 74   6.7  154.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 68   4.0   75.0
# 90   7.3   86.0
# 96   4.4   42.0
# 5    7.1   48.0
# 82   6.5   37.0
# 92   5.2  110.0
# 9    5.1   66.0
# 91   7.5  158.0
# 41   5.4  114.0
# 76   4.9  155.0

# %%
y_train
# Out:
# 13    1
# 70    1
# 83    1
# 15    0
# 57    1
#      ..
# 62    0
# 29    1
# 71    1
# 63    1
# 74    1
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 68    0
# 90    1
# 96    0
# 5     1
# 82    1
# 92    0
# 9     0
# 91    1
# 41    0
# 76    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
#scale
scale = StandardScaler()

# %%
x_train = scale.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.33791857, -0.30348773],
#        [ 0.24925189, -0.01093383],
#        [ 1.31325205,  0.06885359],
#        [-0.81474827,  1.29226079],
#        [ 0.42658525,  0.06885359],
#        [-2.23341516,  2.80822187],
#        [ 0.95858533,  0.62736557],
#        [ 0.69258529,  0.36140749],
#        [-0.99208163,  0.17523683],
#        [-1.79008176, -0.72902066],
#        [-0.72608159, -0.99497875],
#        [-0.01674815, -2.19179013],
#        [ 0.69258529, -0.40987096],
#        [-0.01674815, -1.63327815],
#        [-0.63741491, -0.35667934],
#        [-1.87874844, -0.48965839],
#        [-0.72608159,  0.12204521],
#        [-0.90341495, -0.25029611],
#        [ 0.86991865,  1.90396438],
#        [ 0.07191853, -1.23434103],
#        [ 1.57925209, -0.35667934],
#        [-0.90341495, -1.71306558],
#        [ 0.33791857,  0.36140749],
#        [-0.10541483, -0.56944581],
#        [ 0.16058521, -0.38327515],
#        [-0.99208163,  1.82417696],
#        [ 0.07191853,  0.76034462],
#        [-0.28274819,  0.4145991 ],
#        [ 0.42658525,  0.86672785],
#        [ 0.69258529, -0.99497875],
#        [ 0.78125197, -0.8354039 ],
#        [ 0.42658525, -0.99497875],
#        [-1.08074831,  0.36140749],
#        [-1.08074831,  1.10609013],
#        [-0.72608159,  2.5688596 ],
#        [ 1.40191873,  0.01566198],
#        [-2.41074852,  1.47843145],
#        [-0.99208163, -0.19710449],
#        [-0.99208163,  0.62736557],
#        [ 0.86991865,  0.30821587],
#        [-0.63741491, -0.17050868],
#        [ 1.84525214,  1.0263027 ],
#        [ 1.40191873, -1.02157456],
#        [ 0.07191853, -1.65987396],
#        [ 0.51525193, -0.19710449],
#        [-0.28274819,  0.12204521],
#        [ 0.86991865,  1.26566498],
#        [-0.54874823, -0.54285   ],
#        [-1.08074831,  0.94651528],
#        [ 0.24925189, -0.64923324],
#        [ 0.60391861,  1.45183564],
#        [-0.54874823,  0.20183264],
#        [-1.52408172,  1.93056019],
#        [ 1.13591869,  0.25502425],
#        [-1.16941499, -2.00561947],
#        [ 0.51525193,  0.28162006],
#        [-0.28274819,  1.10609013],
#        [ 0.07191853, -0.64923324],
#        [ 0.78125197,  0.30821587],
#        [ 0.69258529, -0.11731707],
#        [-0.54874823,  0.30821587],
#        [-1.16941499, -1.07476617],
#        [-0.99208163, -1.7662572 ],
#        [ 1.75658546, -1.28753264],
#        [-1.43541504,  0.57417396],
#        [ 1.84525214,  0.57417396],
#        [ 0.78125197,  0.28162006],
#        [ 1.13591869, -0.30348773],
#        [-0.81474827,  0.01566198],
#        [ 1.13591869, -2.05881109],
#        [-0.01674815, -0.09072126],
#        [-0.90341495, -0.96838294],
#        [-0.28274819,  0.33481168],
#        [ 1.22458537,  0.12204521],
#        [-1.25808168,  0.49438653],
#        [-0.19408151,  0.3880033 ],
#        [ 2.19991886, -0.19710449],
#        [-0.19408151,  1.0263027 ],
#        [-1.08074831, -0.40987096],
#        [ 2.0225855 ,  1.07949432],
#        [ 0.86991865, -1.68646977],
#        [-0.72608159,  0.89332366],
#        [-0.01674815,  0.57417396],
#        [-1.16941499, -0.17050868],
#        [ 1.31325205, -1.7662572 ],
#        [-0.01674815, -0.67582905],
#        [ 0.86991865, -0.40987096],
#        [ 0.07191853,  0.12204521],
#        [ 0.24925189,  0.01566198],
#        [ 0.60391861,  0.707153  ]])

# %%
x_test = scale.transform(x_test)

# %%
x_test
# Out:
# array([[-1.79008176, -1.39391588],
#        [ 1.13591869, -1.10136198],
#        [-1.43541504, -2.27157756],
#        [ 0.95858533, -2.11200271],
#        [ 0.42658525, -2.4045566 ],
#        [-0.72608159, -0.46306258],
#        [-0.81474827, -1.63327815],
#        [ 1.31325205,  0.81353623],
#        [-0.54874823, -0.35667934],
#        [-0.99208163,  0.73374881]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# Model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred  = clf.predict(x_test)

# %%
y_test
# Out:
# 68    0
# 90    1
# 96    0
# 5     1
# 82    1
# 92    0
# 9     0
# 91    1
# 41    0
# 76    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0
